# %%
import os

# %%
import pandas as pd

# %%
import numpy as np

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'acs2015-county-data.csv',
#  'asylum-seekers-monthly-2016-12-08-152150.csv',
#  'energydata_complete.csv',
#  'Hamoye Stage A quiz code.ipynb',
#  'hamoyedata.csv',
#  'hamoyeVIZ.ipynb',
#  'map1.html',
#  'MAPPING',
#  'movie-metadata.csv',
#  'myexercise',
#  'mynames.txt',
#  'myprogramlist',
#  'myproject',
#  'MYWEBSITE',
#  'New Text Document.txt',
#  'number.txt',
#  'python for data visualization.ipynb',
#  'pythonHandbook',
#  'Regression lesson.ipynb',
#  'superstore-dataset-dashboarddesign (1).csv',
#  'superstore-dataset-dashboarddesign.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb']

# %%
data=pd.read_csv("asylum-seekers-monthly-2016-12-08-152150.csv")

# %%
data
# Out:
#       Country / territory of asylum/residence       Origin  Year      Month  \
# 0                                     Albania  Afghanistan  2007   November
# 1                                     Albania  Afghanistan  2012  September
# 2                                     Albania  Afghanistan  2015        May
# 3                                     Albania  Afghanistan  2016       June
# 4                                     Albania  Afghanistan  2016       July
# ...                                       ...          ...   ...        ...
# 65494                                  Canada     Viet Nam  2006  September
# 65495                                  Canada     Viet Nam  2006   November
# 65496                                  Canada     Viet Nam  2006   December
# 65497                                  Canada     Viet Nam  2007    January
# 65498                                  Canada     Viet Nam  2007   February
#
#        Value     Date
# 0          1  11/1/07
# ...

# %%
data.head()
# Out:
#   Country / territory of asylum/residence       Origin  Year      Month  \
# 0                                 Albania  Afghanistan  2007   November
# 1                                 Albania  Afghanistan  2012  September
# 2                                 Albania  Afghanistan  2015        May
# 3                                 Albania  Afghanistan  2016       June
# 4                                 Albania  Afghanistan  2016       July
#
#    Value     Date
# 0      1  11/1/07
# 1      1   9/1/12
# 2      0   5/1/15
# 3     18   6/1/16
# 4     19   7/1/16

# %%
data.shape
# Out:
# (65499, 6)

# %%
data.size
# Out:
# 392994

# %%
data.columns
# Out:
# Index(['Country / territory of asylum/residence', 'Origin', 'Year', 'Month',
#        'Value', 'Date'],
#       dtype='object')

# %%
data.head()
# Out:
#   Country / territory of asylum/residence       Origin  Year      Month  \
# 0                                 Albania  Afghanistan  2007   November
# 1                                 Albania  Afghanistan  2012  September
# 2                                 Albania  Afghanistan  2015        May
# 3                                 Albania  Afghanistan  2016       June
# 4                                 Albania  Afghanistan  2016       July
#
#    Value     Date
# 0      1  11/1/07
# 1      1   9/1/12
# 2      0   5/1/15
# 3     18   6/1/16
# 4     19   7/1/16

# %%
data.groupby("Origin")["Value"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-00b707f89fce> in <module>
# ----> 1 data.groupby("Origin")["Value"].sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     389                 sort=sort,
# ...

# %%
data=pd.DataFrame(data.groupby("Origin")["Value"]).sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-61862479d381> in <module>
# ----> 1 data=pd.DataFrame(data.groupby("Origin")["Value"]).sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7892             squeeze=squeeze,
#    7893             observed=observed,
# -> 7894             **kwargs
#    7895         )
#    7896
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2520         raise TypeError("invalid type: {}".format(obj))
#    2521
# -> 2522     return klass(obj, by, **kwds)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
# ...

# %%
data
# Out:
#                   0                                                  1
# 0       Afghanistan  Origin
# Afghanistan    2384714
# Name: Year, dtyp...
# 1           Albania  Origin
# Albania    1565412
# Name: Year, dtype: i...
# 2           Algeria  Origin
# Algeria    2007165
# Name: Year, dtype: i...
# 3           Andorra    Origin
# Andorra    4030
# Name: Year, dtype: int64
# 4            Angola  Origin
# Angola    1151623
# Name: Year, dtype: int64
# ..              ...                                                ...
# 194        Viet Nam  Origin
# Viet Nam    1181738
# Name: Year, dtype: ...
# 195  Western Sahara  Origin
# Western Sahara    68345
# Name: Year, dty...
# 196           Yemen    Origin
# Yemen    720879
# Name: Year, dtype: int64
# 197          Zambia   Origin
# Zambia    204686
# Name: Year, dtype: int64
# 198        Zimbabwe  Origin
# Zimbabwe    626425
# Name: Year, dtype: i...
#
# [199 rows x 2 columns]

# %%
data.head()
# Out:
#                 Year
# Origin
# Afghanistan  2384714
# Albania      1565412
# Algeria      2007165
# Andorra         4030
# Angola       1151623

# %%
year1= data[data["Year"]==2007]

# %%
year1
# Out:
# Empty DataFrame
# Columns: [Year]
# Index: []

# %%
data.head()
# Out:
#              0                                                  1
# 0  Afghanistan  Origin
# Afghanistan    2384714
# Name: Year, dtyp...
# 1      Albania  Origin
# Albania    1565412
# Name: Year, dtype: i...
# 2      Algeria  Origin
# Algeria    2007165
# Name: Year, dtype: i...
# 3      Andorra    Origin
# Andorra    4030
# Name: Year, dtype: int64
# 4       Angola  Origin
# Angola    1151623
# Name: Year, dtype: int64

# %%
data=pd.read_csv("asylum-seekers-monthly-2016-12-08-152150.csv")

# %%
data
# Out:
#       Country / territory of asylum/residence       Origin  Year      Month  \
# 0                                     Albania  Afghanistan  2007   November
# 1                                     Albania  Afghanistan  2012  September
# 2                                     Albania  Afghanistan  2015        May
# 3                                     Albania  Afghanistan  2016       June
# 4                                     Albania  Afghanistan  2016       July
# ...                                       ...          ...   ...        ...
# 65494                                  Canada     Viet Nam  2006  September
# 65495                                  Canada     Viet Nam  2006   November
# 65496                                  Canada     Viet Nam  2006   December
# 65497                                  Canada     Viet Nam  2007    January
# 65498                                  Canada     Viet Nam  2007   February
#
#        Value     Date
# 0          1  11/1/07
# ...

# %%
data.head()
# Out:
#   Country / territory of asylum/residence       Origin  Year      Month  \
# 0                                 Albania  Afghanistan  2007   November
# 1                                 Albania  Afghanistan  2012  September
# 2                                 Albania  Afghanistan  2015        May
# 3                                 Albania  Afghanistan  2016       June
# 4                                 Albania  Afghanistan  2016       July
#
#    Value     Date
# 0      1  11/1/07
# 1      1   9/1/12
# 2      0   5/1/15
# 3     18   6/1/16
# 4     19   7/1/16

# %%
data.groupby("Origin")["Value"].sum()
# Out:
# Origin
# Afghanistan       155025
# Albania            17700
# Algeria            17611
# Andorra                0
# Angola              6084
#                    ...
# Viet Nam            3032
# Western Sahara        72
# Yemen               1315
# Zambia               154
# Zimbabwe            1848
# Name: Value, Length: 199, dtype: int64

# %%
values=pd.DataFrame(data.groupby("Origin")["Value"].sum())

# %%
values
# Out:
#                  Value
# Origin
# Afghanistan     155025
# Albania          17700
# Algeria          17611
# Andorra              0
# Angola            6084
# ...                ...
# Viet Nam          3032
# Western Sahara      72
# Yemen             1315
# Zambia             154
# Zimbabwe          1848
#
# [199 rows x 1 columns]

# %%
values.max()
# Out:
# Value    155025
# dtype: int64

# %%
values.min()
# Out:
# Value    0
# dtype: int64

# %%
pd.DataFrame(values.max())
# Out:
#             0
# Value  155025

# %%
data["Origin"].unique()
# Out:
# array(['Afghanistan', 'Algeria', 'Egypt', 'Azerbaijan', 'Barbados',
#        'Bangladesh', 'Bosnia and Herzegovina', 'Central African Rep.',
#        'China', 'Cameroon', 'Congo', 'Dem. Rep. of the Congo',
#        'Czech Rep.', 'Eritrea', 'Gabon', 'Gambia', 'Palestinian', 'Ghana',
#        'Guinea', 'India', 'Iran (Islamic Rep. of)', 'Iraq', 'Liberia',
#        'Libya', 'Sri Lanka', 'The former Yugoslav Rep. of Macedonia',
#        'Mali', 'Montenegro', 'Nepal', 'Nigeria', 'Pakistan', 'Peru',
#        'Russian Federation', 'Saudi Arabia', 'Senegal', 'Somalia',
#        'Sudan', 'Syrian Arab Rep.', 'Tunisia', 'Turkey', 'Ukraine',
#        'Uzbekistan', 'Colombia',
#        'United Kingdom of Great Britain and Northern Ireland', 'Georgia',
#        'Germany', 'Ireland', 'Albania', 'Costa Rica', 'Cuba', 'Cyprus',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Rep.', 'Ecuador',
#        'Guinea-Bissau', 'Greece', 'Guatemala', 'Guyana',
# ...

# %%
pd.DataFrame(data["Origin"].unique())
# Out:
#                                     0
# 0                         Afghanistan
# 1                             Algeria
# 2                               Egypt
# 3                          Azerbaijan
# 4                            Barbados
# ..                                ...
# 194  Saint Vincent and the Grenadines
# 195          Turks and Caicos Islands
# 196                       Puerto Rico
# 197             Saint Kitts and Nevis
# 198                        San Marino
#
# [199 rows x 1 columns]

# %%
year=data[data["Year"]==2016]

# %%
year
# Out:
#       Country / territory of asylum/residence                  Origin  Year  \
# 3                                     Albania             Afghanistan  2016
# 4                                     Albania             Afghanistan  2016
# 29                                    Albania  Dem. Rep. of the Congo  2016
# 30                                    Albania  Dem. Rep. of the Congo  2016
# 46                                    Albania                   Ghana  2016
# ...                                       ...                     ...   ...
# 65265                                  Canada                Slovakia  2016
# 65266                                  Canada                Slovakia  2016
# 65267                                  Canada                Slovakia  2016
# 65320                              Czech Rep.                   Egypt  2016
# 65321                              Czech Rep.                   Egypt  2016
#
#            Month  Value    Date
# ...

# %%
year.max()
# Out:
# Country / territory of asylum/residence    Czech Rep.
# Origin                                       Zimbabwe
# Year                                             2016
# Month                                       September
# Value                                            2015
# Date                                           9/1/16
# dtype: object

# %%
year.min()
# Out:
# Country / territory of asylum/residence        Albania
# Origin                                     Afghanistan
# Year                                              2016
# Month                                            April
# Value                                                1
# Date                                            1/1/16
# dtype: object

# %%
Albania=data[data["Country / territory of asylum/residence"]=="Albania"]

# %%
Albania
# Out:
#     Country / territory of asylum/residence       Origin  Year      Month  \
# 0                                   Albania  Afghanistan  2007   November
# 1                                   Albania  Afghanistan  2012  September
# 2                                   Albania  Afghanistan  2015        May
# 3                                   Albania  Afghanistan  2016       June
# 4                                   Albania  Afghanistan  2016       July
# ..                                      ...          ...   ...        ...
# 149                                 Albania      Ukraine  2014        May
# 150                                 Albania      Ukraine  2015        May
# 151                                 Albania      Ukraine  2015       June
# 152                                 Albania      Ukraine  2015   November
# 153                                 Albania   Uzbekistan  2006   November
#
#      Value     Date
# 0        1  11/1/07
# 1        1   9/1/12
# ...

# %%
Albania["Value"].sum()
# Out:
# 3358

# %%
Albania["Origin"].max()
# Out:
# 'Uzbekistan'

# %%
Albania["Origin"].min()
# Out:
# 'Afghanistan'

# %%
Albania["Uzbekistan", 2006]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Uzbekistan', 2006)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-25dbe3266b12> in <module>
# ----> 1 Albania["Uzbekistan", 2006]
#
# ...

# %%
year1=Albania[Albania["Year"]==2016]

# %%
year1
# Out:
#     Country / territory of asylum/residence  \
# 3                                   Albania
# 4                                   Albania
# 29                                  Albania
# 30                                  Albania
# 46                                  Albania
# 47                                  Albania
# 75                                  Albania
# 76                                  Albania
# 77                                  Albania
# 78                                  Albania
# 79                                  Albania
# 80                                  Albania
# 81                                  Albania
# 85                                  Albania
# 95                                  Albania
# 97                                  Albania
# 107                                 Albania
# 140                                 Albania
# 141                                 Albania
# 142                                 Albania
# ...

# %%
year1["Value"].max()
# Out:
# 587

# %%
pd.DataFrame[year1["Value"].max()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-499e83abae62> in <module>
# ----> 1 pd.DataFrame[year1["Value"].max()]
#
# TypeError: 'type' object is not subscriptable

# %%
year1.max()
# Out:
# Country / territory of asylum/residence      Albania
# Origin                                        Turkey
# Year                                            2016
# Month                                      September
# Value                                            587
# Date                                          9/1/16
# dtype: object

# %%
data.head()
# Out:
#   Country / territory of asylum/residence       Origin  Year      Month  \
# 0                                 Albania  Afghanistan  2007   November
# 1                                 Albania  Afghanistan  2012  September
# 2                                 Albania  Afghanistan  2015        May
# 3                                 Albania  Afghanistan  2016       June
# 4                                 Albania  Afghanistan  2016       July
#
#    Value     Date
# 0      1  11/1/07
# 1      1   9/1/12
# 2      0   5/1/15
# 3     18   6/1/16
# 4     19   7/1/16

# %%
data.isnull().any()
# Out:
# Country / territory of asylum/residence    False
# Origin                                     False
# Year                                       False
# Month                                      False
# Value                                      False
# Date                                       False
# dtype: bool

# %%
june=data.query("Year==2015 & Month== 'June'")

# %%
june
# Out:
#       Country / territory of asylum/residence                  Origin  Year  \
# 40                                    Albania                 Eritrea  2015
# 68                                    Albania  Iran (Islamic Rep. of)  2015
# 84                                    Albania                    Iraq  2015
# 119                                   Albania                 Somalia  2015
# 121                                   Albania                   Sudan  2015
# ...                                       ...                     ...   ...
# 64783                                  Canada                   Spain  2015
# 64863                              Czech Rep.                 Algeria  2015
# 65152                                  Cyprus                  Jordan  2015
# 65253                                  Canada                Slovakia  2015
# 65318                              Czech Rep.                   Egypt  2015
#
#       Month  Value    Date
# 40     June      5  6/1/15
# ...

# %%
june.max()
# Out:
# Country / territory of asylum/residence    Czech Rep.
# Origin                                       Zimbabwe
# Year                                             2015
# Month                                            June
# Value                                            2415
# Date                                           6/1/15
# dtype: object

# %%
june.min()
# Out:
# Country / territory of asylum/residence        Albania
# Origin                                     Afghanistan
# Year                                              2015
# Month                                             June
# Value                                                0
# Date                                            6/1/15
# dtype: object

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-304fa4ce4ebd> in <module>
# ----> 1 data.head()
#
# NameError: name 'data' is not defined

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data=pd.read_csv("asylum-seekers-monthly-2016-12-08-152150.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-afca7c8a8d33> in <module>
# ----> 1 data=pd.read_csv("asylum-seekers-monthly-2016-12-08-152150.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv("asylum-seekers-monthly-2016-12-08-152150.csv")

# %%
data
# Out:
#       Country / territory of asylum/residence       Origin  Year      Month  \
# 0                                     Albania  Afghanistan  2007   November
# 1                                     Albania  Afghanistan  2012  September
# 2                                     Albania  Afghanistan  2015        May
# 3                                     Albania  Afghanistan  2016       June
# 4                                     Albania  Afghanistan  2016       July
# ...                                       ...          ...   ...        ...
# 65494                                  Canada     Viet Nam  2006  September
# 65495                                  Canada     Viet Nam  2006   November
# 65496                                  Canada     Viet Nam  2006   December
# 65497                                  Canada     Viet Nam  2007    January
# 65498                                  Canada     Viet Nam  2007   February
#
#        Value     Date
# 0          1  11/1/07
# ...

# %%
data.head()
# Out:
#   Country / territory of asylum/residence       Origin  Year      Month  \
# 0                                 Albania  Afghanistan  2007   November
# 1                                 Albania  Afghanistan  2012  September
# 2                                 Albania  Afghanistan  2015        May
# 3                                 Albania  Afghanistan  2016       June
# 4                                 Albania  Afghanistan  2016       July
#
#    Value     Date
# 0      1  11/1/07
# 1      1   9/1/12
# 2      0   5/1/15
# 3     18   6/1/16
# 4     19   7/1/16

# %%
data.Year
# Out:
# 0        2007
# 1        2012
# 2        2015
# 3        2016
# 4        2016
#          ...
# 65494    2006
# 65495    2006
# 65496    2006
# 65497    2007
# 65498    2007
# Name: Year, Length: 65499, dtype: int64

# %%
year=data[data["Year"]==2016]

# %%
year
# Out:
#       Country / territory of asylum/residence                  Origin  Year  \
# 3                                     Albania             Afghanistan  2016
# 4                                     Albania             Afghanistan  2016
# 29                                    Albania  Dem. Rep. of the Congo  2016
# 30                                    Albania  Dem. Rep. of the Congo  2016
# 46                                    Albania                   Ghana  2016
# ...                                       ...                     ...   ...
# 65265                                  Canada                Slovakia  2016
# 65266                                  Canada                Slovakia  2016
# 65267                                  Canada                Slovakia  2016
# 65320                              Czech Rep.                   Egypt  2016
# 65321                              Czech Rep.                   Egypt  2016
#
#            Month  Value    Date
# ...

# %%
year.isnull()
# Out:
#        Country / territory of asylum/residence  Origin   Year  Month  Value  \
# 3                                        False   False  False  False  False
# 4                                        False   False  False  False  False
# 29                                       False   False  False  False  False
# 30                                       False   False  False  False  False
# 46                                       False   False  False  False  False
# ...                                        ...     ...    ...    ...    ...
# 65265                                    False   False  False  False  False
# 65266                                    False   False  False  False  False
# 65267                                    False   False  False  False  False
# 65320                                    False   False  False  False  False
# 65321                                    False   False  False  False  False
#
#         Date
# 3      False
# 4      False
# ...

# %%
year.isnull().any()
# Out:
# Country / territory of asylum/residence    False
# Origin                                     False
# Year                                       False
# Month                                      False
# Value                                      False
# Date                                       False
# dtype: bool

# %%
year.describe()
# Out:
#          Year        Value
# count  2035.0  2035.000000
# mean   2016.0    39.382310
# std       0.0   126.035749
# min    2016.0     1.000000
# 25%    2016.0     2.000000
# 50%    2016.0     6.000000
# 75%    2016.0    24.000000
# max    2016.0  2015.000000

# %%
may=data[data["Month"]=="May"]

# %%
may
# Out:
#       Country / territory of asylum/residence                  Origin  Year  \
# 2                                     Albania             Afghanistan  2015
# 19                                    Albania                   China  2006
# 20                                    Albania                   China  2009
# 21                                    Albania                   China  2011
# 26                                    Albania  Dem. Rep. of the Congo  2012
# ...                                       ...                     ...   ...
# 65433                                  Canada                Viet Nam  2001
# 65445                                  Canada                Viet Nam  2002
# 65456                                  Canada                Viet Nam  2003
# 65468                                  Canada                Viet Nam  2004
# 65490                                  Canada                Viet Nam  2006
#
#       Month  Value    Date
# 2       May      0  5/1/15
# ...

# %%
may.max()
# Out:
# Country / territory of asylum/residence    Czech Rep.
# Origin                                       Zimbabwe
# Year                                             2016
# Month                                             May
# Value                                            1816
# Date                                           5/1/99
# dtype: object

# %%
may1=may.query("Year==2015 & Origin=='China'")

# %%
may1
# Out:
#       Country / territory of asylum/residence Origin  Year Month  Value  \
# 3977                                Australia  China  2015   May    132
# 26828                                 Belgium  China  2015   May      7
# 47309                                  Canada  China  2015   May    134
#
#          Date
# 3977   5/1/15
# 26828  5/1/15
# 47309  5/1/15

# %%
may2 =pd.DataFrame({"country / territory of asylum/residence":["NIgeria"], "Origin":["China"], "Year":[2015], "Month":["May"], "Value":[256], "Date":["year"=2015,"month"="may", "day"= 1]})
# Out:
#   File "<ipython-input-43-3e5e99af54df>", line 1
#     may2 =pd.DataFrame({"country / territory of asylum/residence":["NIgeria"], "Origin":["China"], "Year":[2015], "Month":["May"], "Value":[256], "Date":["year"=2015,"month"="may", "day"= 1]})
#                                                                                                                                                                 ^
# SyntaxError: invalid syntax

# %%
may2
# Out:
#   country / territory of asylum/residence Origin  Year Month  Value      Date
# 0                                 NIgeria  China  2015   May    256  0.333333

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
import os

# %%
import pandas as pd

# %%
import numpy as np

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'acs2015-county-data.csv',
#  'asylum-seekers-monthly-2016-12-08-152150.csv',
#  'asylums data page.ipynb',
#  'energydata_complete.csv',
#  'Hamoye Stage A quiz code.ipynb',
#  'hamoyedata.csv',
#  'hamoyeVIZ.ipynb',
#  'map1.html',
#  'MAPPING',
#  'movie-metadata.csv',
#  'myexercise',
#  'mynames.txt',
#  'myprogramlist',
#  'myproject',
#  'MYWEBSITE',
#  'New Text Document.txt',
#  'number.txt',
#  'python for data visualization.ipynb',
#  'pythonHandbook',
#  'Regression lesson.ipynb',
#  'superstore-dataset-dashboarddesign (1).csv',
#  'superstore-dataset-dashboarddesign.csv',
#  'Untitled.ipynb']

# %%
data=pd.read_csv("asylum-seekers-monthly-2016-12-08-152150.csv")

# %%
data
# Out:
#       Country / territory of asylum/residence       Origin  Year      Month  \
# 0                                     Albania  Afghanistan  2007   November
# 1                                     Albania  Afghanistan  2012  September
# 2                                     Albania  Afghanistan  2015        May
# 3                                     Albania  Afghanistan  2016       June
# 4                                     Albania  Afghanistan  2016       July
# ...                                       ...          ...   ...        ...
# 65494                                  Canada     Viet Nam  2006  September
# 65495                                  Canada     Viet Nam  2006   November
# 65496                                  Canada     Viet Nam  2006   December
# 65497                                  Canada     Viet Nam  2007    January
# 65498                                  Canada     Viet Nam  2007   February
#
#        Value     Date
# 0          1  11/1/07
# ...
